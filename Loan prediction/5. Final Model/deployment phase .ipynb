# %%
import pickle

# %%
loaded_model = pickle.load(open("loan_prediction_model.sav","rb"))
y_pred = loaded_model.predict([[2, 0.165, 742, 12.48, 7]])
# Out:
# C:\Anaconda3\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([1])
